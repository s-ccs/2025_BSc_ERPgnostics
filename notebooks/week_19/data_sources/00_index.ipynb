# %% [markdown]
# # Data Source Notebooks
#
# Each real data source has its own import/load notebook. Plot utilities stay shared through `notebooks/week_15/try_new_data_helpers.jl` and the existing Week 15 overview helpers.
#
# - [01_imported_bi2013a_public.ipynb](01_imported_bi2013a_public.ipynb)
# - [01_imported_bi2014a_public.ipynb](01_imported_bi2014a_public.ipynb)
# - [01_imported_bi2014b_public.ipynb](01_imported_bi2014b_public.ipynb)
# - [01_imported_bi2015a_public.ipynb](01_imported_bi2015a_public.ipynb)
# - [01_imported_bi2015b_public.ipynb](01_imported_bi2015b_public.ipynb)
# - [01_imported_bigp3bci_studya_public.ipynb](01_imported_bigp3bci_studya_public.ipynb)
# - [01_imported_bnci_008_2014_public.ipynb](01_imported_bnci_008_2014_public.ipynb)
# - [01_imported_cattan2019_vr_public.ipynb](01_imported_cattan2019_vr_public.ipynb)
# - [01_imported_confidence_perceptual_decisions.ipynb](01_imported_confidence_perceptual_decisions.ipynb)
# - [01_imported_ds003517_sub001_derived.ipynb](01_imported_ds003517_sub001_derived.ipynb)
# - [01_imported_eegeyenet_saccades.ipynb](01_imported_eegeyenet_saccades.ipynb)
# - [01_imported_erp_core_lrp_clean.ipynb](01_imported_erp_core_lrp_clean.ipynb)
# - [01_imported_erp_core_mmn_clean.ipynb](01_imported_erp_core_mmn_clean.ipynb)
# - [01_imported_erp_core_n170_clean.ipynb](01_imported_erp_core_n170_clean.ipynb)
# - [01_imported_erp_core_n2pc_clean.ipynb](01_imported_erp_core_n2pc_clean.ipynb)
# - [01_imported_erp_core_n400_clean.ipynb](01_imported_erp_core_n400_clean.ipynb)
# - [01_imported_erp_core_p3_clean.ipynb](01_imported_erp_core_p3_clean.ipynb)
# - [01_imported_erpbci_public.ipynb](01_imported_erpbci_public.ipynb)
# - [01_imported_eye_eeg_freeviewing_fixations.ipynb](01_imported_eye_eeg_freeviewing_fixations.ipynb)
# - [01_imported_eye_eeg_reading_fixations.ipynb](01_imported_eye_eeg_reading_fixations.ipynb)
# - [01_imported_eye_eeg_sceneviewing_tobii_fixations.ipynb](01_imported_eye_eeg_sceneviewing_tobii_fixations.ipynb)
# - [01_imported_fixations_dataset.ipynb](01_imported_fixations_dataset.ipynb)
# - [01_imported_kilo_word_erp.ipynb](01_imported_kilo_word_erp.ipynb)
# - [01_imported_mrc_ox_gonogo.ipynb](01_imported_mrc_ox_gonogo.ipynb) — excluded; login-gated source, not counted/plotted
# - [01_imported_muspelheim_alday2017_public.ipynb](01_imported_muspelheim_alday2017_public.ipynb)
# - [01_imported_nencki_symfonia_srt.ipynb](01_imported_nencki_symfonia_srt.ipynb)
# - [01_imported_nod_eeg_public.ipynb](01_imported_nod_eeg_public.ipynb)
# - [01_imported_openalex_jung_citations.ipynb](01_imported_openalex_jung_citations.ipynb) — auxiliary citation download, not an ERP-image source
# - [01_imported_openneuro_gonogo_ds002680.ipynb](01_imported_openneuro_gonogo_ds002680.ipynb)
# - [01_imported_roamm_reading_fixations.ipynb](01_imported_roamm_reading_fixations.ipynb)
# - [01_imported_saccade_onset_face_vr.ipynb](01_imported_saccade_onset_face_vr.ipynb)
# - [01_imported_zuco2_nr_public.ipynb](01_imported_zuco2_nr_public.ipynb)
# - [02_new_eeget_rsod.ipynb](02_new_eeget_rsod.ipynb)
# - [02_new_eegeyenet_saccades.ipynb](02_new_eegeyenet_saccades.ipynb)
# - [02_new_raccoons_reading.ipynb](02_new_raccoons_reading.ipynb)
# - [02_new_roamm_reading.ipynb](02_new_roamm_reading.ipynb)
# - [02_new_unfold_facefreeview.ipynb](02_new_unfold_facefreeview.ipynb)
# - [02_new_visuomotor_chenguang.ipynb](02_new_visuomotor_chenguang.ipynb)
# - [02_new_zuco2_reading_fixations.ipynb](02_new_zuco2_reading_fixations.ipynb)
